# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Results/RSA_results.csv')
df_columns = df.keys()
df_columns
# Out:
# Index(['Input Word Length', 'Enc Time (ms)', 'Dec Time (ms)',
#        'CPU Enc Time (ms)', 'CPU Dec Time (ms)', 'Enc Memory Usage (MiB)',
#        'Dec Memory Usage (MiB)', 'Enc Throughput (kB/s)',
#        'Dec Throughput (kB/s)'],
#       dtype='object')

# %%
df.head(17)
# Out:
#     Input Word Length  Enc Time (ms)  Dec Time (ms)  CPU Enc Time (ms)  \
# 0                  10           0.00           0.00               0.00
# 1                  25           0.00           0.00               0.00
# 2                  50           0.00           0.00               0.00
# 3                 100           0.00           0.00               0.00
# 4                 200           0.00           0.00               0.00
# 5                 250           0.00           0.00               0.00
# 6                 500           0.00           0.00               0.00
# 7                1000           0.00           0.00               0.00
# 8                2500           0.00           0.00               0.00
# 9                5000           0.00           0.00               0.00
# 10               7500           0.00           0.00               0.00
# 11              10000           0.00           0.00               0.00
# 12              20000         483.43         612.84             482.12
# 13              25000         559.22         736.34             530.20
# 14              50000        1432.34        1643.73            1430.75
# 15              75000        2132.60        2432.82            2105.32
# 16             100000        3076.38        3582.81            2993.64
#
#     CPU Dec Time (ms)  Enc Memory Usage (MiB)  Dec Memory Usage (MiB)  \
# 0                0.00                    41.9                    41.5
# 1                0.00                    41.8                    41.6
# 2                0.00                    41.9                    41.9
# 3                0.00                    41.9                    42.2
# 4                0.00                    42.0                    41.7
# 5                0.00                    42.1                    41.5
# 6                0.00                    42.1                    41.8
# 7                0.00                    42.3                    41.7
# 8                0.00                    42.5                    41.7
# 9                0.00                    41.8                    42.0
# 10               0.00                    42.0                    42.2
# 11               0.00                    42.3                    41.9
# 12             592.23                    42.3                    41.8
# 13             693.54                    42.3                    42.0
# 14            1531.48                    42.5                    41.8
# 15            2142.52                    42.5                    41.9
# 16            3242.53                    42.6                    41.9
#
#     Enc Throughput (kB/s)  Dec Throughput (kB/s)
# 0                     NaN                    NaN
# 1                     NaN                    NaN
# 2                     NaN                    NaN
# 3                     NaN                    NaN
# 4                     NaN                    NaN
# 5                     NaN                    NaN
# 6                     NaN                    NaN
# 7                     NaN                    NaN
# 8                     NaN                    NaN
# 9                     NaN                    NaN
# 10                    NaN                    NaN
# 11                    NaN                    NaN
# 12                    NaN                    NaN
# 13                 301.90                 229.28
# 14                 235.74                 205.42
# 15                 237.49                 208.19
# 16                 219.51                 188.49

# %% [markdown]
# ## The values marked NaN in Throughput columns mean that they are not defined and mean essentially Infinity.

# %%
# # replace - with NaN
# df = df.replace("-", np.nan)
# df.head(8)

# %%
df.plot(x=df_columns[0], y=df_columns[1:3], kind='line', marker="o")
plt.xticks(rotation=25)
plt.xlabel('Input Word Length')
plt.ylabel('Time (ms)')
plt.title('AES - Input Word Length vs Encryption Time')
plt.grid()
plt.legend()
plt.show()

# %%
df.plot(x=df_columns[0], y=df_columns[3:5], kind='line', marker="o")
plt.xticks(rotation=25)
plt.xlabel('Input Word Length')
plt.ylabel('CPU Time (ms)')
plt.title('AES - Input Word Length vs CPU Time')
plt.grid()
plt.legend()
plt.show()

# %%
df.plot(x=df_columns[0], y=df_columns[5:7], kind='line', marker="o")
plt.xticks(rotation=25)
plt.xlabel('Input Word Length')
plt.ylabel('Memory Usage (MiB)')
plt.title('AES - Input Word Length vs Memory Usage')
plt.grid()
plt.legend()
plt.show()

# %%
df.plot(x=df_columns[0], y=df_columns[7:9], kind='line', marker="o")
plt.xticks(rotation=25)
plt.xlabel('Input Word Length')
plt.ylabel('Throughput (kB/s)')
plt.title('AES - Input Word Length vs Throughput')
plt.grid()
plt.legend()
plt.show()
